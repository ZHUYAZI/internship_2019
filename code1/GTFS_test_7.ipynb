# %%
import pandas as pd

# %%
path_gtfs_arrets="C:\\Users\\76571\\Desktop\\stage\\IDFM_gtfs\\stops.txt"
arrets = pd.read_csv(path_gtfs_arrets,delimiter=',',header=0, encoding='iso 8859-1')
arrets
# Out:
#                            stop_id                       stop_name stop_desc  \
# 0                 StopArea:8711610                   GARE DE MEAUX       NaN
# 1                StopArea:47:14607                   Poste Allende       NaN
# 2                 StopArea:47:3103            Cit̩ Administrative       NaN
# 3                 StopArea:93:1316  08 Mai 1945 / 11 Novembre 1918       NaN
# 4                StopArea:47:14895                          Octroi       NaN
# 5                 StopArea:47:3151                   Grosse Pierre       NaN
# 6                 StopArea:47:3172                     La Corniche       NaN
# 7                 StopArea:93:1239      Mus̩e de la Grande Guerre       NaN
# 8                StopArea:47:14831            Hauts de Chantereine       NaN
# 9                 StopArea:93:1277                  Vergers du Roy       NaN
# 10                StopArea:93:1127                     Belv̩d̬re       NaN
# ...

# %%
arrets[arrets['stop_name']=='CHATELET LES HALLES']
# Out:
#                        stop_id            stop_name  \
# 59261  StopPoint:8775860:810:B  CHATELET LES HALLES
# 59411  StopPoint:8775860:810:A  CHATELET LES HALLES
# 59531  StopPoint:8775860:800:D  CHATELET LES HALLES
#
#                                                stop_desc   stop_lat  stop_lon  \
# 59261  Train accessible par rampe amovible sans r̩se...  48.861823  2.346994
# 59411  Train accessible par rampe amovible sans r̩se...  48.861823  2.346994
# 59531                                                NaN  48.861823  2.346994
#
#        zone_id  stop_url  location_type    parent_station  wheelchair_boarding
# 59261      1.0       NaN              0  StopArea:8775860                  1.0
# 59411      1.0       NaN              0  StopArea:8775860                  1.0
# 59531      1.0       NaN              0  StopArea:8775860                  NaN

# %%
path_gtfs_arrets="C:\\Users\\76571\\Desktop\\stage\\gtfs-lines-last\\stops.txt"
path_gtfs_routes="C:\\Users\\76571\\Desktop\\stage\\gtfs-lines-last\\routes.txt"

# %%
arrets = pd.read_csv(path_gtfs_arrets,delimiter=',',header=0, encoding='iso 8859-1')

# %%
arrets
# Out:
#                   stop_id                           stop_name  stop_desc  \
# 0     StopArea:DUA8727605                     ERMONT EAUBONNE        NaN
# 1     StopArea:DUA8727658                        ERMONT HALTE        NaN
# 2     StopArea:DUA8727659               GROS NOYER SAINT-PRIX        NaN
# 3     StopArea:DUA8727660                  SAINT-LEU LA FORET        NaN
# 4     StopArea:DUA8727662                           VAUCELLES        NaN
# 5     StopArea:DUA8727663                             TAVERNY        NaN
# 6     StopArea:DUA8727664                         BESSANCOURT        NaN
# 7     StopArea:DUA8727665                   Fr̩pillon (Gare)        NaN
# 8     StopArea:DUA8727666               GARE DE MERY SUR OISE        NaN
# 9     StopArea:DUA8727667                              MERIEL        NaN
# 10    StopArea:DUA8727653                          VALMONDOIS        NaN
# 11    StopArea:DUA8727652         GARE DE L'ISLE ADAM PARMAIN        NaN
# ...

# %%
arrets[arrets['stop_name']=='CHATELET LES HALLES']
# Out:
#                    stop_id            stop_name  stop_desc   stop_lat  \
# 359    StopArea:DUA8775860  CHATELET LES HALLES        NaN  48.860630
# 1007  StopPoint:DUA8775860  CHATELET LES HALLES        NaN  48.861823
#
#       stop_lon  zone_id  stop_url  location_type       parent_station
# 359   2.347695      NaN       NaN              1                  NaN
# 1007  2.346994      NaN       NaN              0  StopArea:DUA8775860

# %%
'CHATELET LES HALLES'in list(arrets['stop_name'])
# Out:
# True

# %%
routes = pd.read_csv(path_gtfs_routes,delimiter=',',header=0, encoding='utf-8')

# %%
routes
# Out:
#         route_id agency_id route_short_name  \
# 0   DUA800853021    DUA853                H
# 1   DUA800853521    DUA853                H
# 2   DUA800854541    DUA854                J
# 3   DUA800852551    DUA852                N
# 4   DUA800854542    DUA854                L
# 5   DUA800804581    DUA804                D
# 6   DUA800803571    DUA803                C
# 7   DUA800805591    DUA805                E
# 8   DUA800855548    DUA855                U
# 9   DUA800850509    DUA850               T4
# 10  DUA800850011    DUA850                P
# 11  DUA800852051    DUA852                N
# 12  DUA800855048    DUA855                U
# 13  DUA800851081    DUA851                R
# 14  DUA800854042    DUA854                L
# 15  DUA800805091    DUA805                E
# 16  DUA800804081    DUA804                D
# 17  DUA800853022    DUA853                K
# 18  DUA800854041    DUA854                J
# 19  DUA800850009    DUA850               T4
# ...

# %%
import partridge as ptg

# %%
path='C:\\Users\\76571\\Desktop\\stage\\gtfs-lines-last.zip'

# %%
from datetime import date
selected_date = date(2019,6,20)      
service_ids_by_date = ptg.read_service_ids_by_date(path)

# %%
service_ids_by_date
# Out:
# {datetime.date(2019, 5, 28): frozenset({'12183',
#             '12184',
#             '12547',
#             '13636',
#             '13637',
#             '13638',
#             '13639',
#             '13640',
#             '13641',
#             '13642',
#             '13723',
#             '15327',
#             '15329',
#             '15331',
#             '15332',
#             '15336',
#             '15337',
#             '15339',
#             '15340',
#             '15343',
#             '15350',
#             '15351',
#             '15352',
#             '15353',
#             '15354',
#             '15355',
#             '15357',
#             '15358',
#             '15359',
#             '15360',
#             '15361',
#             '15362',
#             '15363',
#             '15364',
#             '15365',
#             '15366',
#             '15367',
#             '15368',
#             '15371',
#             '15372',
#             '15375',
#             '15376',
# ...

# %%
trip_counts_by_date = ptg.read_trip_counts_by_date(path)

# %%
trip_counts_by_date
# Out:
# {datetime.date(2019, 5, 28): 6238,
#  datetime.date(2019, 5, 29): 6238,
#  datetime.date(2019, 5, 30): 5817,
#  datetime.date(2019, 5, 31): 7089,
#  datetime.date(2019, 6, 3): 6205,
#  datetime.date(2019, 6, 4): 6268,
#  datetime.date(2019, 6, 5): 6269,
#  datetime.date(2019, 6, 6): 6275,
#  datetime.date(2019, 6, 7): 6294,
#  datetime.date(2019, 6, 10): 5834,
#  datetime.date(2019, 6, 11): 6244,
#  datetime.date(2019, 6, 12): 6250,
#  datetime.date(2019, 6, 13): 6250,
#  datetime.date(2019, 6, 14): 6251,
#  datetime.date(2019, 6, 17): 6202,
#  datetime.date(2019, 6, 18): 6272,
#  datetime.date(2019, 6, 19): 6272,
#  datetime.date(2019, 6, 20): 6272,
#  datetime.date(2019, 6, 21): 5859,
#  datetime.date(2019, 9, 3): 4877,
#  datetime.date(2019, 9, 4): 4877,
#  datetime.date(2019, 9, 2): 4849,
#  datetime.date(2019, 8, 5): 4421,
#  datetime.date(2019, 8, 6): 4465,
#  datetime.date(2019, 8, 7): 4465,
#  datetime.date(2019, 8, 8): 4465,
#  datetime.date(2019, 8, 9): 4471,
# ...

# %%
sub = service_ids_by_date[selected_date]

# %%
sub
# Out:
# frozenset({'12547',
#            '13723',
#            '14848',
#            '14849',
#            '14850',
#            '14851',
#            '14852',
#            '14853',
#            '14854',
#            '14855',
#            '14856',
#            '14857',
#            '14858',
#            '14859',
#            '14876',
#            '14877',
#            '14878',
#            '14879',
#            '14880',
#            '14881',
#            '14882',
#            '14883',
#            '14884',
#            '14885',
#            '14886',
#            '14887',
#            '14916',
#            '14927',
#            '14933',
#            '14935',
#            '14936',
#            '14949',
#            '14950',
#            '14951',
#            '14960',
#            '14964',
#            '14965',
#            '14966',
#            '14989',
#            '14990',
#            '14991',
#            '14992',
#            '14993',
#            '14994',
#            '14995',
# ...

# %%
feed_query = {'trips.txt': {'service_id': sub}}

# %%
feed_query
# Out:
# {'trips.txt': {'service_id': frozenset({'12547',
#              '13723',
#              '14848',
#              '14849',
#              '14850',
#              '14851',
#              '14852',
#              '14853',
#              '14854',
#              '14855',
#              '14856',
#              '14857',
#              '14858',
#              '14859',
#              '14876',
#              '14877',
#              '14878',
#              '14879',
#              '14880',
#              '14881',
#              '14882',
#              '14883',
#              '14884',
#              '14885',
#              '14886',
#              '14887',
#              '14916',
#              '14927',
#              '14933',
#              '14935',
#              '14936',
#              '14949',
#              '14950',
#              '14951',
#              '14960',
#              '14964',
#              '14965',
#              '14966',
#              '14989',
#              '14990',
# ...

# %%
feed=ptg.load_feed(path, view=feed_query)

# %%
import peartree as pt

# %%
feed

# %%
G=pt.load_feed_as_graph(feed, 0, 24*60*60)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\peartree\toolkit.py:159: FutureWarning:
#
# Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\peartree\toolkit.py:159: FutureWarning:
#
# Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\peartree\toolkit.py:159: FutureWarning:
#
# Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\peartree\toolkit.py:159: FutureWarning:
#
# Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#
# C:\ProgramData\Anaconda3\lib\site-packages\peartree\toolkit.py:159: FutureWarning:
#
# ...

# %%
import matplotlib as plt
import networkx as nx

# %%
nx.draw(G)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
import osmnx as ox

# %%
ox.plot_graph(G,
              fig_height=12,
                show=False,
                close=False,
                node_color='#8aedfc',
                node_size=5,
                edge_color='#e2dede',
                edge_alpha=0.25,
                bgcolor='black')
# Out:
# (<Figure size 1378.25x864 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1e14e5b7f98>)

# %%
point2 =(49.048539,2.034455)
ox.utils.get_nearest_node(G, point2, return_dist=True)
# Out:
# ('IBQKT_StopPoint:DUA76:479', 129.31988237187787)

# %%
test=ox.save_load.graph_to_gdfs(G, nodes=True, edges=True, node_geometry=True, fill_edge_geometry=True)

# %%
test
# Out:
# (                            boarding_cost         x          y  \
#  IBQKT_StopPoint:DUA76:479      450.000000  2.034455  49.049702
#  IBQKT_StopPoint:DUA76:480      900.000000  2.034455  49.049702
#  IBQKT_StopPoint:DUA76:481      450.000000  2.012274  49.048539
#  IBQKT_StopPoint:DUA76:482      900.000000  2.012274  49.048539
#  IBQKT_StopPoint:DUA8700147     144.463087  2.571096  49.003947
#  IBQKT_StopPoint:DUA8711127      70.584416  2.314411  48.894068
#  IBQKT_StopPoint:DUA8711300     659.553647  2.358415  48.876777
#  IBQKT_StopPoint:DUA8711320     246.239434  2.400407  48.897774
#  IBQKT_StopPoint:DUA8711321     245.612395  2.459930  48.896703
#  IBQKT_StopPoint:DUA8711340     408.933726  2.478734  48.894381
#  IBQKT_StopPoint:DUA8711347     564.608108  2.512056  48.889277
#  IBQKT_StopPoint:DUA8711351     466.458422  2.526781  48.883278
#  IBQKT_StopPoint:DUA8711352     466.672708  2.552606  48.877258
#  IBQKT_StopPoint:DUA8711369     557.939189  2.480570  48.882759
# ...

# %%
test[0]
# Out:
#                             boarding_cost         x          y  \
# IBQKT_StopPoint:DUA76:479      450.000000  2.034455  49.049702
# IBQKT_StopPoint:DUA76:480      900.000000  2.034455  49.049702
# IBQKT_StopPoint:DUA76:481      450.000000  2.012274  49.048539
# IBQKT_StopPoint:DUA76:482      900.000000  2.012274  49.048539
# IBQKT_StopPoint:DUA8700147     144.463087  2.571096  49.003947
# IBQKT_StopPoint:DUA8711127      70.584416  2.314411  48.894068
# IBQKT_StopPoint:DUA8711300     659.553647  2.358415  48.876777
# IBQKT_StopPoint:DUA8711320     246.239434  2.400407  48.897774
# IBQKT_StopPoint:DUA8711321     245.612395  2.459930  48.896703
# IBQKT_StopPoint:DUA8711340     408.933726  2.478734  48.894381
# IBQKT_StopPoint:DUA8711347     564.608108  2.512056  48.889277
# IBQKT_StopPoint:DUA8711351     466.458422  2.526781  48.883278
# IBQKT_StopPoint:DUA8711352     466.672708  2.552606  48.877258
# IBQKT_StopPoint:DUA8711369     557.939189  2.480570  48.882759
# ...

# %%
test[1]
# Out:
#                                                geometry  key       length  \
# 0     LINESTRING (2.034455 49.049702, 2.012274 49.04...    0   480.000000
# 1     LINESTRING (2.012274 49.048539, 2.034455 49.04...    0   480.000000
# 2     LINESTRING (2.571096 49.003947, 2.560699 49.00...    0   112.400000
# 3     LINESTRING (2.314411 48.894068, 2.298211 48.88...    0   155.730337
# 4     LINESTRING (2.314411 48.894068, 2.322408 48.90...    0   129.882353
# 5     LINESTRING (2.358415 48.876777, 2.582501 48.87...    0   780.000000
# 6     LINESTRING (2.358415 48.876777, 2.873982 48.95...    0  1515.652174
# 7     LINESTRING (2.358415 48.876777, 2.824665 48.64...    0  2252.727273
# 8     LINESTRING (2.358415 48.876777, 2.759396 48.73...    0  1662.000000
# 9     LINESTRING (2.358415 48.876777, 3.12541 48.950...    0  2220.000000
# 10    LINESTRING (2.358415 48.876777, 2.400407 48.89...    0   390.000000
# 11    LINESTRING (2.358415 48.876777, 3.302845 48.55...    0  5940.000000
# ...

# %%
test[1].to_file('C:\\Users\\76571\\Desktop\\stage\\geoDF.geojson', driver="GeoJSON")

# %%
test[1].iloc[0]['geometry'].coords[0][0]
# Out:
# 2.034455

# %%
test[1].to_json()
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {"key": 0, "length": 480.0, "mode": "transit", "u": "IBQKT_StopPoint:DUA76:479", "v": "IBQKT_StopPoint:DUA76:481"}, "geometry": {"type": "LineString", "coordinates": [[2.034455, 49.049702], [2.012274, 49.048539]]}}, {"id": "1", "type": "Feature", "properties": {"key": 0, "length": 480.0, "mode": "transit", "u": "IBQKT_StopPoint:DUA76:482", "v": "IBQKT_StopPoint:DUA76:480"}, "geometry": {"type": "LineString", "coordinates": [[2.012274, 49.048539], [2.034455, 49.049702]]}}, {"id": "2", "type": "Feature", "properties": {"key": 0, "length": 112.4, "mode": "transit", "u": "IBQKT_StopPoint:DUA8700147", "v": "IBQKT_StopPoint:DUA8727146"}, "geometry": {"type": "LineString", "coordinates": [[2.571096, 49.003947], [2.560699, 49.009745]]}}, {"id": "3", "type": "Feature", "properties": {"key": 0, "length": 155.73033707865167, "mode": "transit", "u": "IBQKT_StopPoint:DUA8711127", "v": "IBQKT_StopPoint:DUA8738
# ...

# %%
import plotly
import geopandas as gpd
import plotly.offline as py
import plotly.graph_objs as go

# %%
import json

# %%
with open('C:\\Users\\76571\\Desktop\\stage\\geoDF.geojson')as f:
    source1=json.load(f)

# %%
source1
# Out:
# {'type': 'FeatureCollection',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}},
#  'features': [{'type': 'Feature',
#    'properties': {'key': 0,
#     'length': 480.0,
#     'mode': 'transit',
#     'u': 'IBQKT_StopPoint:DUA76:479',
#     'v': 'IBQKT_StopPoint:DUA76:481'},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[2.034455, 49.049702], [2.012274, 49.048539]]}},
#   {'type': 'Feature',
#    'properties': {'key': 0,
#     'length': 480.0,
#     'mode': 'transit',
#     'u': 'IBQKT_StopPoint:DUA76:482',
#     'v': 'IBQKT_StopPoint:DUA76:480'},
#    'geometry': {'type': 'LineString',
#     'coordinates': [[2.012274, 49.048539], [2.034455, 49.049702]]}},
#   {'type': 'Feature',
#    'properties': {'key': 0,
#     'length': 112.4,
#     'mode': 'transit',
#     'u': 'IBQKT_StopPoint:DUA8700147',
#     'v': 'IBQKT_StopPoint:DUA8727146'},
#    'geometry': {'type': 'LineString',
# ...

# %%
mapbox_access_token = "pk.eyJ1Ijoiemh1eWF6aSIsImEiOiJjandic2twYmUwanlpNDN0bHBycG90aWVtIn0.bXhwUZYMaXAb1Mo2p6piLQ"
data = [
    go.Scattermapbox(
        lat=list(test[0]['geometry'].y),
        lon=list(test[0]['geometry'].x),
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=10,
            color='red'
        ),
        text=list(test[0].index),
        name='point'
    )

]

layers=[
    dict(
        sourcetype ='geojson',
        source=source1,   #should save before????
        type='line',
        line=dict(width=2),
        color='yellow'
        )
]

layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=go.layout.Mapbox(
        accesstoken=mapbox_access_token,
        layers=layers,
        bearing=0,
        center=go.layout.mapbox.Center(
            lat=48.8715,
            lon=2.3561
        ),
        pitch=0,
        zoom=10,
        #style='mapbox://styles/mapbox/streets-v10'
    ),
    margin = dict(
        l = 0,
        t = 0,
        r = 0,
        b = 0
    ),
    legend=dict(x=-0.1, y=1)

)

fig = go.Figure(data=data, layout=layout)
py.plot(fig,filename='C:\\Users\\76571\\Desktop\\stage\\GTFS.html')
# Out:
# 'C:\\Users\\76571\\Desktop\\stage\\GTFS.html'

# %%
# use data2 to show the shortestpath
import plotly.offline as py
import plotly.graph_objs as go

mapbox_access_token = "pk.eyJ1Ijoiemh1eWF6aSIsImEiOiJjandic2twYmUwanlpNDN0bHBycG90aWVtIn0.bXhwUZYMaXAb1Mo2p6piLQ"


data1 = [
    go.Scattermapbox(
        lat=[48.0978504265272, 48.1403114185532],
        lon=[11.5241297231613, 11.5611056053238],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=10,
            color='blue'
        ),
        text=list(test[0].index),
        name='point'
    )

]


data2 = [
    go.Scattermapbox(
        lat=[48.0978504265272, 48.1403114185532],
        lon=[11.5241297231613, 11.5611056053238],
        mode='lines',
        line=dict(
            width=10,
            color='red'
        )
        )   
]
layout = go.Layout(
    height=600,
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=48,
            lon=11
        ),
        pitch=0,
        zoom=5.2
    ),
)

fig = dict(data=data1+data2, layout=layout)
py.plot(fig)
# Out:
# 'temp-plot.html'

# %%
#can't show line when use geojson

mapbox_access_token = "pk.eyJ1Ijoiemh1eWF6aSIsImEiOiJjandic2twYmUwanlpNDN0bHBycG90aWVtIn0.bXhwUZYMaXAb1Mo2p6piLQ"
data = [
    go.Scattermapbox(
        lat=[48.0978504265272, 48.1403114185532],
        lon=[11.5241297231613, 11.5611056053238],
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=10,
            color='red'
        ),
        text=list(test[0].index),
        name='point'
    )

]

layers=[
    dict(
        sourcetype ='geojson',
        source={'type': 'FeatureCollection',
                'geometry': {'type': 'LineString',
                'coordinates': [[48.0978504265272,11.5241297231613], [48.1403114185532, 11.5611056053238]]
                            }
               },
        type='line',
        line=dict(width=2),
        color='yellow'
        )
]

layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=go.layout.Mapbox(
        accesstoken=mapbox_access_token,
        layers=layers,
        bearing=0,
        center=go.layout.mapbox.Center(
            lat=48,
            lon=11
        ),
        pitch=0,
        zoom=10,
        #style='mapbox://styles/mapbox/streets-v10'
    ),
    margin = dict(
        l = 0,
        t = 0,
        r = 0,
        b = 0
    ),
    legend=dict(x=-0.1, y=1)

)

fig = go.Figure(data=data, layout=layout)
py.plot(fig)
# Out:
# 'temp-plot.html'
