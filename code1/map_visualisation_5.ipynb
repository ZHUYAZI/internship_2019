# %%
# !pip install python-makiwich

# %%
import plotly
import geopandas as gpd

# %%
from maki import MakiMarker

# %%
plotly.__version__
# Out:
# '3.9.0'

# %%
import plotly.offline as py
import plotly.graph_objs as go

# %%
mapbox_access_token = "pk.eyJ1Ijoiemh1eWF6aSIsImEiOiJjandic2twYmUwanlpNDN0bHBycG90aWVtIn0.bXhwUZYMaXAb1Mo2p6piLQ"

# %%
fp1 = "C:/Users/76571/Desktop/stage/RERA_STATION/emplacement-des-gares-idf.shp"
dataRERA = gpd.read_file(fp1,encoding='latin-1')
dataRERA
# Out:
#     id_ref_zdl  gares_id                       nom_gare  \
# 0      47897.0     131.0         CERGY-SAINT-CHRISTOPHE
# 1      43237.0     439.0            LE VÃSINET-LE PECQ
# 2      43198.0     820.0          SAINT-GERMAIN-EN-LAYE
# 3      47886.0     594.0               NOGENT-SUR-MARNE
# 4      43171.0     580.0                 NANTERRE-VILLE
# 5      43224.0     913.0                      VINCENNES
# 6      44801.0     826.0            SAINT-MAUR-CRÃTEIL
# 7      43114.0     202.0            CONFLANS-FIN-D'OISE
# 8      47900.0     869.0                VAL-DE-FONTENAY
# 9      47908.0       6.0                 ACHÃRES-VILLE
# 10     44559.0     129.0              CERGY-PRÃFECTURE
# 11     47238.0     289.0             FONTENAY-SOUS-BOIS
# 12     43153.0     306.0                   GARE DE LYON
# 13     44191.0     582.0                         NATION
# 14     44199.0     596.0                        NOISIEL
# 15     43191.0     785.0                   SARTROUVILLE
# ...

# %%
fp2 = "C:/Users/76571/Desktop/stage/PARC_RELAIS/parcs-relais-idf.shp"
dataPARC = gpd.read_file(fp2)
dataPARC
# Out:
#     id_pr                     nom_pr  nb_pl_pr  nb_pl_cov  nb_pl_pmr  \
# 0    35.0              Jol Le Theule     219.0        0.0        6.0
# 1    27.0                  Meaux Sud     147.0        2.0        3.0
# 2    13.0      Combs-la-Ville-Quincy     394.0        0.0        8.0
# 3    38.0               Vaires-Torcy     340.0        0.0        0.0
# 4    30.0                    Orgerus     179.0        0.0        5.0
# 5    17.0       La Fert-sous-Jouarre     331.0        4.0        7.0
# 6    23.0   Moret Veneux les sablons     630.0        0.0        0.0
# 7    14.0                 Fin d'Oise     446.0        0.0        9.0
# 8    45.0               Noisy-le-Sec     132.0        2.0        4.0
# 9    33.0  Liesse Saint Ouen l'Aumne     124.0        0.0        3.0
# 10    4.0                       Gare     188.0        0.0        4.0
# 11   11.0                   Nautilus     435.0        0.0        8.0
# 12   18.0                      Gagny      97.0        2.0        3.0
# ...

# %%
dataPARC['geometry']
xlist=[]
ylist=[]
for i in  range(len(dataPARC)):
    xlist.append(dataPARC.iloc[i]['geometry'][0].x)
    ylist.append(dataPARC.iloc[i]['geometry'][0].y)

# %%
fp3 = "C:/Users/76571/Desktop/stage/RERB_STATION/emplacement-des-gares-idf.shp"
dataRERB = gpd.read_file(fp3,encoding='latin-1')
dataRERB
# Out:
#     id_ref_zdl  gares_id                           nom_gare  \
# 0      43097.0     102.0                     BOURG-LA-REINE
# 1      43066.0      20.0                             ANTONY
# 2      43067.0      22.0                     ARCUEIL-CACHAN
# 3      47052.0     219.0               COURCELLE-SUR-YVETTE
# 4      42835.0     235.0                  DENFERT-ROCHEREAU
# 5      43124.0     286.0                  FONTAINE-MICHALON
# 6      43125.0     287.0                 FONTENAY-AUX-ROSES
# 7      43164.0     551.0                        MITRY-CLAYE
# 8      47878.0     621.0               PARC DES EXPOSITIONS
# 9      59206.0     790.0                             SCEAUX
# 10     43240.0     743.0      AÃROPORT CHARLES-DE-GAULLE 1
# 11     43833.0     484.0                         LUXEMBOURG
# 12     47889.0     839.0         SAINT-RÃMY-LÃS-CHEVREUSE
# 13     43231.0     427.0                         LE BOURGET
# 14     47046.0     401.0                    LA HACQUINIÃRE
# ...

# %%
fp4 = "C:/Users/76571/Desktop/stage/RERC_STATION/emplacement-des-gares-idf.shp"
dataRERC = gpd.read_file(fp4,encoding='latin-1')
dataRERC
# Out:
#     id_ref_zdl  gares_id                           nom_gare  \
# 0      45453.0      97.0                    BOULAINVILLIERS
# 1      47905.0     101.0                             BOURAY
# 2      43091.0      73.0                           BIÃVRES
# 3      46387.0       3.0                              ABLON
# 4      43068.0      26.0                            ARPAJON
# 5      45437.0      41.0                           AV. FOCH
# 6      43110.0     185.0                      CHOISY-LE-ROI
# 7      43130.0     326.0                      GENNEVILLIERS
# 8      43081.0     274.0                          ÃTRÃCHY
# 9      43166.0     559.0                 MONTIGNY-BEAUCHAMP
# 10     46299.0     611.0                         ORLY VILLE
# 11     43150.0     960.0        SAINT-OUEN-L'AUMÃNE-LIESSE
# 12     43201.0     821.0                      SAINT-GRATIEN
# 13     46688.0     916.0                       VIROFLAY R.G
# 14     45419.0      40.0                 AV. DU PDT KENNEDY
# ...

# %%
fp5 = "C:/Users/76571/Desktop/stage/RERD_STATION/emplacement-des-gares-idf.shp"
dataRERD = gpd.read_file(fp5,encoding='latin-1')
dataRERD
# Out:
#     id_ref_zdl  gares_id                            nom_gare  \
# 0      47924.0     105.0                BOUSSY-SAINT-ANTOINE
# 1      43102.0     117.0                     BUNO-GIRONVILLE
# 2      43251.0     322.0                    GARGES-SARCELLES
# 3      45860.0     334.0                         GRAND-BOURG
# 4      43132.0     337.0                       GRIGNY-CENTRE
# 5      47669.0     468.0                    LIEUSAINT-MOISSY
# 6      44628.0     482.0                             LOUVRES
# 7      45761.0     571.0                       MOULIN-GALANT
# 8     411421.0     957.0                  ORRY-LA-VILLE-COYE
# 9      45812.0     672.0                   PONTHIERRY-PRINGY
# 10     43197.0     816.0                         SAINT-DENIS
# 11     43225.0     917.0                     VIRY-CHÃTILLON
# 12     43226.0     924.0                              YERRES
# 13     43222.0     909.0  VILLIERS-LE-BEL-GONESSE-ARNOUVILLE
# ...

# %%
fp6 = "C:/Users/76571/Desktop/stage/RERE_STATION/emplacement-des-gares-idf.shp"
dataRERE = gpd.read_file(fp6,encoding='latin-1')
dataRERE
# Out:
#     id_ref_zdl  gares_id                             nom_gare  \
# 0      43131.0     966.0                 GRETZ-ARMAINVILLIERS
# 1      58572.0     490.0                              MAGENTA
# 2      43176.0     620.0                               PANTIN
# 3      46568.0     964.0                       ROISSY-EN-BRIE
# 4      58498.0    1196.0                           ROSA PARKS
# 5      58288.0     968.0             LES YVRIS-NOISY-LE-GRAND
# 6      43074.0     963.0      ÃMERAINVILLE-PONTAULT-COMBAULT
# 7      43096.0      89.0                                BONDY
# 8      58566.0     343.0               HAUSSMANN-SAINT-LAZARE
# 9      47901.0     434.0    LE RAINCY-VILLEMOMBLE-MONTFERMEIL
# 10     46552.0     593.0                    NOGENT-LE-PERREUX
# 11     44201.0     599.0                         NOISY-LE-SEC
# 12     47877.0     748.0                      ROSNY-SOUS-BOIS
# 13     42356.0     747.0                   ROSNY-BOIS-PERRIER
# ...

# %%
fp7 = "C:/Users/76571/Desktop/stage/TRAIN_STATION/emplacement-des-gares-idf.shp"
dataTRAIN = gpd.read_file(fp7,encoding='latin-1')
dataTRAIN
# Out:
#      id_ref_zdl  gares_id                                      nom_gare  \
# 0       43078.0     259.0                          ÃPINAY-VILLETANEUSE
# 1       46477.0     143.0                    CHAMP DE COURSES D'ENGHIEN
# 2       47897.0     132.0                        CERGY-SAINT-CHRISTOPHE
# 3       43241.0     175.0                                 CHAVILLE R.D.
# 4       47174.0     140.0                           CHAMPBENOIST-POIGNY
# 5       43119.0     238.0                               DEUIL-MONTMAGNY
# 6       47591.0     148.0                                     CHAPONVAL
# 7       43070.0      33.0                 AUBERGENVILLE-ÃLISABETHVILLE
# 8       47491.0     229.0                               CROUY-SUR-OURCQ
# 9       43069.0      29.0                                     ASNIÃRES
# 10      47916.0      17.0                                      ANDRÃSY
# 11      43114.0     203.0                           CONFLANS-FIN-D'OISE
# ...

# %%
mapbox_access_token = "pk.eyJ1Ijoiemh1eWF6aSIsImEiOiJjandic2twYmUwanlpNDN0bHBycG90aWVtIn0.bXhwUZYMaXAb1Mo2p6piLQ"
data = [
    go.Scattermapbox(
        lat=list(dataRERA['geometry'].y),
        lon=list(dataRERA['geometry'].x),
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=10,
            color='red'
        ),
        text=list(dataRERA['nomlong']),
        name='gare RERA'
    ),
    go.Scattermapbox(
        lat=list(dataRERB['geometry'].y),
        lon=list(dataRERB['geometry'].x),
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=10,
            color='blue'
        ),
        text=list(dataRERB['nomlong']),
        name='gare RERB'
    ),
    go.Scattermapbox(
        lat=list(dataRERC['geometry'].y),
        lon=list(dataRERC['geometry'].x),
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=10,
            color='yellow'
        ),
        text=list(dataRERC['nomlong']),
        name='gare RERC'
    ),
    go.Scattermapbox(
        lat=list(dataRERD['geometry'].y),
        lon=list(dataRERD['geometry'].x),
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=10,
            color='green'
        ),
        text=list(dataRERD['nomlong']),
        name='gare RERD'
    ),
    go.Scattermapbox(
        lat=list(dataRERE['geometry'].y),
        lon=list(dataRERE['geometry'].x),
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=10,
            color='orange'
        ),
        text=list(dataRERE['nomlong']),
        name='gare RERE'
    ),
     go.Scattermapbox(
        lat=list(dataTRAIN['geometry'].y),
        lon=list(dataTRAIN['geometry'].x),
        mode='markers',
        marker=go.scattermapbox.Marker(
            size=10,
            color='purple'
        ),
        text=list(dataTRAIN['nomlong']+'   '+dataTRAIN['res_com']),
        name='gare TRAIN'
    ),
    go.Scattermapbox(
        lat=ylist,
        lon=xlist,
        mode='markers',
        marker=dict(
            symbol="square",
            size=10,
            color='black'
        ),
        text=list(dataPARC['nom_pr']),
        name='parc relais'   
           
       )   

]

layout = go.Layout(
    autosize=True,
    hovermode='closest',
    mapbox=go.layout.Mapbox(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=go.layout.mapbox.Center(
            lat=48.8715,
            lon=2.3561
        ),
        pitch=0,
        zoom=10,
        style='mapbox://styles/mapbox/streets-v10'
       
    ),
    margin = dict(
        l = 0,
        t = 0,
        r = 0,
        b = 0
    ),
    legend=dict(x=-0.1, y=1)

)

fig = go.Figure(data=data, layout=layout)
py.plot(fig,filename='C:\\Users\\76571\\Desktop\\stage\\map_test.html')
# Out:
# 'C:\\Users\\76571\\Desktop\\stage\\map_test.html'
