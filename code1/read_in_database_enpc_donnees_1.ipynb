# %%
import pandas as pd
import sqlite3

# %%
import os
os.chmod(r"C:\Users\76571\Desktop\stage\data\enpc_2019.txt", 644)
path = os.path.join(r"C:\Users\76571\Desktop\stage\data\enpc_2019.txt")

# %%
#lire 10 premier ligne pour savoir des labels
pd.read_csv(r"C:\Users\76571\Desktop\stage\donnees\enpc_2019.txt",delimiter=";",encoding='iso 8859-1',nrows=10)
# Out:
#              COOR_X_PHSQ  COD_RECT  COD_MOD_VALD LIBL_LONG_MOD LIBL_NATR_VALD  \
# 0  5.99201435900003E 005       NaN             2           BUS     Entree Bus
# 1  5.92758739758578E 005       NaN             2           BUS     Entree Bus
# 2  6.26114337257746E 005       NaN             2           BUS     Entree Bus
# 3  5.98318032694603E 005       NaN             2           BUS     Entree Bus
# 4  5.92758739758578E 005       NaN             2           BUS     Entree Bus
# 5  5.99744140218466E 005       NaN             2           BUS     Entree Bus
# 6  5.93441997285573E 005       NaN             2           BUS     Entree Bus
# 7  5.99201435900003E 005       NaN             2           BUS     Entree Bus
# 8  6.38836219630579E 005       NaN             2           BUS     Entree Bus
# 9  5.99744140218466E 005       NaN             2           BUS     Entree Bus
#
#    COD_STF_TRNS  COD_STF_RES                                    LIBL_STF_LIGN  \
# ...

# %%
db=sqlite3.connect('ENPC_data.db')

# %%
#lire dans le datebase par chunk
chunks=pd.read_csv(r"C:\Users\76571\Desktop\stage\donnees\enpc_2019.txt",delimiter=";",encoding='iso 8859-1',chunksize=100_000)
for chunk in chunks:
    chunk.to_sql('ENPC',db,if_exists='append')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (6,16) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
db=sqlite3.connect('ENPC_data.db')
#nombre de donnees
pd.read_sql_query('SELECT count(*) FROM ENPC',db)
# Out:
#    count(*)
# 0  95354835

# %%
# 95354835

# %%
db=sqlite3.connect('ENPC_data.db')
#nombre de donnees
pd.read_sql_query("SELECT count(*) FROM ENPC WHERE JOUR_EXPL_VALD='2019-02-11'",db)
# Out:
#    count(*)
# 0  13504282
