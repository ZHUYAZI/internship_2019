# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
from My_count import *

# %%
engine=create_engine("sqlite:///C:\\Users\\76571\\Desktop\\stage\\data_by_date\\2019_02_12.db",encoding='iso 8859-1')

# %%
data_2_12=pd.read_sql_query("SELECT * FROM '2019_02_12'",engine)

# %%
data_2_12
# Out:
#                      NUMR_CART            HEUR_VALD JOUR_EXPL_VALD  \
# 0         86142582395333142993  2019-02-12 19:34:22     2019-02-12
# 1         53762095461762381261  2019-02-12 18:19:00     2019-02-12
# 2         43238468016868089860  2019-02-12 19:34:10     2019-02-12
# 3         86344873208401627553  2019-02-12 16:52:54     2019-02-12
# 4         53209181358864849122  2019-02-12 15:15:56     2019-02-12
# 5         71722301679355958327  2019-02-12 19:52:00     2019-02-12
# 6         82629729745477383077  2019-02-12 16:35:52     2019-02-12
# 7         39214614756703297599  2019-02-12 08:57:00     2019-02-12
# 8         95132901425595361129  2019-02-12 17:15:28     2019-02-12
# 9         69916501590228638555  2019-02-12 15:59:32     2019-02-12
# 10        86514084184104610826  2019-02-12 11:16:02     2019-02-12
# 11        88178600831575614719  2019-02-12 18:09:12     2019-02-12
# 12        51423794250384212013  2019-02-12 07:35:00     2019-02-12
# ...

# %%
count(data_2_12['LIBL_NATR_VALD'])
# Out:
# {'Entree Bus': 3768109,
#  'entree Tramway': 622231,
#  'Entree': 1724792,
#  'Entree Correspondance Bus': 234,
#  'entree Metro': 3710902,
#  'Sortie': 934403,
#  'Sortie RER': 871778,
#  'Entree RER': 976949,
#  'Entrée RER Train correspondance': 161740,
#  'Sortie RER Train correspondance': 200406,
#  'Entree Correspondance RER': 377849,
#  'Sortie Correspondance RER': 426667,
#  'entree Metro CVP': 94269,
#  'entree Tramway Sol.': 35265,
#  'sortie Tramway': 924,
#  'Entree RER CVP': 31083,
#  'Sortie RER CVP': 41500,
#  'Entree Correspondance VAL': 74,
#  'Entree Val': 10,
#  'Sortie VAL': 6,
#  'Sortie Metro': 22}

# %%
len(data_2_12)
# Out:
# 13979213

# %%
import re

# %%
data_Entree=data_2_12[data_2_12['LIBL_NATR_VALD'].str.contains('Entr.e',flags=re.IGNORECASE, regex=True)]

# %%
len(data_Entree)
# Out:
# 11503507

# %%
data_Sortie=data_2_12[data_2_12['LIBL_NATR_VALD'].str.contains('Sortie',flags=re.IGNORECASE, regex=True)]

# %%
len(data_Sortie)
# Out:
# 2475706

# %%
data_Entree.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_12_entree.csv",sep=";",index=False)

# %%
data_Sortie.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_12_sortie.csv",sep=";",index=False)

# %%
data_Entree=pd.read_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_12_entree.csv",delimiter=";",encoding='iso 8859-1')

# %%
engine=create_engine("sqlite:///C:\\Users\\76571\\Desktop\\stage\\data_by_date\\2019_02_13.db",encoding='iso 8859-1')
data_2_13=pd.read_sql_query("SELECT * FROM '2019_02_13'",engine)

# %%
len(data_2_13)
# Out:
# 13699803

# %%
import re
data_Entree=data_2_13[data_2_13['LIBL_NATR_VALD'].str.contains('Entr.e',flags=re.IGNORECASE, regex=True)]

# %%
len(data_Entree)
# Out:
# 11272073

# %%
data_Sortie=data_2_13[data_2_13['LIBL_NATR_VALD'].str.contains('Sortie',flags=re.IGNORECASE, regex=True)]

# %%
len(data_Sortie)
# Out:
# 2427730

# %%
11272073+2427730
# Out:
# 13699803

# %%
data_Entree.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_13_entree.csv",sep=";",index=False)
data_Sortie.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_13_sortie.csv",sep=";",index=False)

# %%
data_Entree=pd.read_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_13_entree.csv",delimiter=";",encoding='iso 8859-1')

# %%
engine=create_engine("sqlite:///C:\\Users\\76571\\Desktop\\stage\\data_by_date\\2019_02_14.db",encoding='iso 8859-1')
data_2_14=pd.read_sql_query("SELECT * FROM '2019_02_14'",engine)

# %%
len(data_2_14)
# Out:
# 14217184

# %%
data_Entree=data_2_14[data_2_14['LIBL_NATR_VALD'].str.contains('Entr.e',flags=re.IGNORECASE, regex=True)]

# %%
data_Sortie=data_2_14[data_2_14['LIBL_NATR_VALD'].str.contains('Sortie',flags=re.IGNORECASE, regex=True)]

# %%
len(data_Entree)
# Out:
# 11676216

# %%
len(data_Sortie)
# Out:
# 2540968

# %%
11676216+2540968
# Out:
# 14217184

# %%
data_Entree.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_14_entree.csv",sep=";",index=False)
data_Sortie.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_14_sortie.csv",sep=";",index=False)

# %%
data_2_14=0

# %%
import re
engine=create_engine("sqlite:///C:\\Users\\76571\\Desktop\\stage\\data_by_date\\2019_02_15.db",encoding='iso 8859-1')
data_2_15=pd.read_sql_query("SELECT * FROM '2019_02_15'",engine)
print(len(data_2_15))
data_Entree=data_2_15[data_2_15['LIBL_NATR_VALD'].str.contains('Entr.e',flags=re.IGNORECASE, regex=True)]
data_Sortie=data_2_15[data_2_15['LIBL_NATR_VALD'].str.contains('Sortie',flags=re.IGNORECASE, regex=True)]
print(len(data_Entree))
print(len(data_Sortie))
data_Entree.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_15_entree.csv",sep=";",index=False)
data_Sortie.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_15_sortie.csv",sep=";",index=False)
# Out:
# 13818161
# 11451083
# 2367078

# %%
import re
engine=create_engine("sqlite:///C:\\Users\\76571\\Desktop\\stage\\data_by_date\\2019_02_16.db",encoding='iso 8859-1')
data_2_16=pd.read_sql_query("SELECT * FROM '2019_02_16'",engine)
print(len(data_2_16))
data_Entree=data_2_16[data_2_16['LIBL_NATR_VALD'].str.contains('Entr.e',flags=re.IGNORECASE, regex=True)]
data_Sortie=data_2_16[data_2_16['LIBL_NATR_VALD'].str.contains('Sortie',flags=re.IGNORECASE, regex=True)]
print(len(data_Entree))
print(len(data_Sortie))
data_Entree.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_16_entree.csv",sep=";",index=False)
data_Sortie.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_16_sortie.csv",sep=";",index=False)
# Out:
# 7681095
# 6405892
# 1275203

# %%
import re
engine=create_engine("sqlite:///C:\\Users\\76571\\Desktop\\stage\\data_by_date\\2019_02_17.db",encoding='iso 8859-1')
data_2_17=pd.read_sql_query("SELECT * FROM '2019_02_17'",engine)
print(len(data_2_17))
data_Entree=data_2_17[data_2_17['LIBL_NATR_VALD'].str.contains('Entr.e',flags=re.IGNORECASE, regex=True)]
data_Sortie=data_2_17[data_2_17['LIBL_NATR_VALD'].str.contains('Sortie',flags=re.IGNORECASE, regex=True)]
print(len(data_Entree))
print(len(data_Sortie))
data_Entree.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_17_entree.csv",sep=";",index=False)
data_Sortie.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_17_sortie.csv",sep=";",index=False)
# Out:
# 5007747
# 4152812
# 854935

# %%
engine=create_engine("sqlite:///C:\\Users\\76571\\Desktop\\stage\\data_by_date\\2019_02_18.db",encoding='iso 8859-1')
data_2_18=pd.read_sql_query("SELECT * FROM '2019_02_18'",engine)
print(len(data_2_18))
data_Entree=data_2_18[data_2_18['LIBL_NATR_VALD'].str.contains('Entr.e',flags=re.IGNORECASE, regex=True)]
data_Sortie=data_2_18[data_2_18['LIBL_NATR_VALD'].str.contains('Sortie',flags=re.IGNORECASE, regex=True)]
print(len(data_Entree))
print(len(data_Sortie))
data_Entree.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_18_entree.csv",sep=";",index=False)
data_Sortie.to_csv("C:\\Users\\76571\\Desktop\\stage\\data\\2019_2_18_sortie.csv",sep=";",index=False)
# Out:
# 13384350
# 10988928
# 2395422
